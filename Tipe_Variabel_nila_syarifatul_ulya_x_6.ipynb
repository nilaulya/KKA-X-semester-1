# %% [markdown]
# <a href="https://colab.research.google.com/github/nilaulya/KKA-X-semester-1/blob/main/Tipe_Variabel_nila_syarifatul_ulya_x_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama:nila syarifatul ulya
#
# kelas:x.6
#
# absen:27

# %% [markdown]
# #konsep dasar variabel

# %%
print("nilaulya77.2025@gmail.com")
print("nilaulya77.2025@gmail.com")
print("nilaulya77.2025@gmail.com")
print("nilaulya77.2025@gmail.com")
# Out:
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com

# %%
email_user_1="nilaulya77.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com
# nilaulya77.2025@gmail.com

# %% [markdown]
# #peraturan penulisan variabel

# %%
# penulisan variabel hanya boleh huruf, angka, under score
#email user 1 ="nilaulya77.2025@gmail.com"

emailuser1="nilaulya77.2025@gmail.com"
print(emailuser1)
# Out:
# nilaulya77.2025@gmail.com

# %%
#tidak boleh di dahului angka
1emailuser="nilaulya77.2025@gmail"
print(1username)
# Out:
#   File "/tmp/ipython-input-1187492308.py", line 2
#     1emailuser="nilaulya77.2025@gmail"
#     ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case senstive

nama_user_1="nila syarifatul ulya"
print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1365624208.py in <cell line: 0>()
#       2
#       3 nama_user_1="nila syarifatul ulya"
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#hanya boleh menggunakan huruf angka dan underscore
berat_badan = 45

print(berat_badan)
# Out:
#   File "/tmp/ipython-input-3098396842.py", line 2
#     berat badan = 45
#           ^
# SyntaxError: invalid syntax

# %%
beratbadan = 45
print(beratbadan)
# Out:
# 45

# %%
#tidak boleh diawali oleh angka
1_nama_ortu_siswa ="budi"

print(1_nama_ortu_siswa)
# Out:
#   File "/tmp/ipython-input-338859835.py", line 2
#     1_nama_ortu_siswa ="budi"
#      ^
# SyntaxError: invalid decimal literal

# %%
nama_ortu_siswa_1="budi"
print(nama_ortu_siswa_1)
# Out:
# budi

# %%
namaortusiswa1="adi"
print(namaortusiswa1)
# Out:
# adi

# %%
#tidak boleh menggunakan kata kunci python
if="aji mulyono"
# Out:
#   File "/tmp/ipython-input-68921009.py", line 2
#     if="aji mulyono"
#       ^
# SyntaxError: invalid syntax

# %%
IF = "aji mulyono"
print(IF)
# Out:
# aji mulyono

# %%
message_to_print="muhammad syakoer"
print(message_to_print)
# Out:
# muhammad syakoer

# %%
Print="muhammad syakoer"
Print(Print)

# %% [markdown]
# Jenis tipe variabel

# %%
a="hadziq"
print (a)
type (a)
# Out:
# hadziq
# str

# %%
b =1.9
print(b)
type(b)
# Out:
# 1.9
# float

# %%
c = -9
del print
print(c)
type (c)
# Out:
# -9
# int

# %% [markdown]
# Operator Perbandingan

# %%
print (6 >= 6)
# Out:
# True

# %%
print (8 == 9)
# Out:
# False

# %%
print (8 != 9)
# Out:
# True

# %%
print (8<10)
# Out:
# True

# %%
print (8>10)
# Out:
# False

# %%
print (not (5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print (7 <= 10 or 2 !=2)
# Out:
# True

# %%
print (not (0==1 and 1 !=1))
# Out:
# True

# %% [markdown]
# mengubah tipe variabel.

# %%
g =8
print(g)
type (g)
# Out:
# 8
# int

# %%
g = str(g)
print(g)
type(g)
# Out:
# 8
# str

# %%
g = float(g)
print(g)
type(g)
# Out:
# 8.0
# float

# %% [markdown]
# penulisan operator di python

# %%
#tanpa variabel
del print
print(100+10)
# Out:
# 110

# %%
#operator di simpan di variabel
telur_ayam_chanifa=100
telur_ayam_shinta=10

print(telur_ayam_chanifa+telur_ayam_shinta)
# Out:
# 110

# %%
#hasil operator di simpang ke variabel
total_telur_ayam =100+10

print(total_telur_ayam)
# Out:
# 110

# %%
#operand dan hasil operasi disimpan ke variabel
telur_ayam_chanifa=100
telur_ayam_shinta=10

total_telur_ayam=telur_ayam_chanifa+telur_ayam_shinta
print(total_telur_ayam)
# Out:
# 110

# %% [markdown]
# jenis operasi aritmatika di python

# %%
#penjumlahan
apel_alecia =15
apel_silla =20

jumlah_apel= apel_alecia+apel_silla
print(jumlah_apel)
# Out:
# 35

# %%
#pengurangan
apel_alecia=15
apel_silla=20
jumlah_apel=apel_silla-apel_alecia
print(jumlah_apel)
# Out:
# 5

# %% [markdown]
# assignment

# %%
#single assignment
usia =18
print(usia)
# Out:
# 18

# %%
#multiple assignment
nama_siswa, usia_siswa="budi",16
print(nama_siswa)
print(usia_siswa)
# Out:
# budi
# 16

# %%
p, q, r=1, 2,"hello"
print(r)
print(p)
print(q)
# Out:
# hello
# 1
# 2

# %%
p, q, r=1, 2,"hello", "shinta"
print(r)
print(p)
print(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1093694327.py in <cell line: 0>()
# ----> 1 p, q, r=1, 2,"hello", "shinta"
#       2 print(r)
#       3 print(p)
#       4 print(q)
#
# ValueError: too many values to unpack (expected 3)

# %%
p, q, r=1, 2,"hello", "shinta"
print(r)
print(p)
print(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1093694327.py in <cell line: 0>()
# ----> 1 p, q, r=1, 2,"hello", "shinta"
#       2 print(r)
#       3 print(p)
#       4 print(q)
#
# ValueError: too many values to unpack (expected 3)

# %%
#chain assignment
nilai_ayyas=nilai_hadziq=100
print (nilai_ayyas)
print(nilai_hadziq)
# Out:
# 100
# 100
